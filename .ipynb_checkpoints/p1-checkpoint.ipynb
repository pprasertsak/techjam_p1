# %% [markdown]
# # Problem 1: Non-Performing Loan Flag Prediction from Credit Card Information

# %%
import os

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %% [markdown]
# ## Data Sources

# %%
data_dir = 'data'

trxfile = os.path.join(data_dir, 'trx.csv')
cardfile = os.path.join(data_dir, 'card.csv')
custfile = os.path.join(data_dir, 'cust.csv')
trainfile = os.path.join(data_dir, 'train.csv')
testfile = os.path.join(data_dir, 'test.csv')

# card_no, label
train_df = pd.read_csv(trainfile, header=None)
# card_no
test_df = pd.read_csv(testfile, header=None)

# %% [markdown]
# ## Data Exploration

# %%
trx_df = pd.read_csv(trxfile)
trx_df.head()
# Out:
#             card_no             txn_date  txn_hour  txn_amount  mer_cat_code  \
# 0  1234000000010196  2016-08-03 00:00:00        19       250.0          5411
# 1  1234000000020315  2016-08-03 00:00:00        19       400.0          6300
# 2  1234000000013283  2016-08-03 00:00:00        19       500.0          6300
# 3  1234000000027192  2016-08-03 00:00:00        19        50.0          7832
# 4  1234000000006620  2016-08-03 00:00:00        19      1300.0          5812
#
#    mer_id
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
trx_df.describe()
# Out:
#             card_no       txn_hour    txn_amount   mer_cat_code         mer_id
# count  6.272910e+05  627291.000000  6.272910e+05  627291.000000  627291.000000
# mean   1.234000e+15      14.484032  1.719821e+03    5813.004499    7341.813264
# std    9.577850e+03       4.671009  1.743873e+04     871.895787   10816.667616
# min    1.234000e+15       0.000000  5.000000e+01     742.000000       0.000000
# 25%    1.234000e+15      11.000000  2.500000e+02    5411.000000       0.000000
# 50%    1.234000e+15      15.000000  5.000000e+02    5641.000000       0.000000
# 75%    1.234000e+15      18.000000  1.050000e+03    6011.000000   14013.000000
# max    1.234000e+15      23.000000  5.630400e+06    9405.000000   28726.000000

# %%
card_df = pd.read_csv(cardfile)
card_df.head()
# Out:
#             card_no  bill_cyc               pos_dt      cst_id  \
# 0  1234000000023349        20  2017-02-23 00:00:00  1000004674
# 1  1234000000007292        17  2017-02-23 00:00:00  1000010084
# 2  1234000000018889        20  2017-02-23 00:00:00  1000009114
# 3  1234000000016887        17  2017-02-23 00:00:00  1000013313
# 4  1234000000026997        17  2017-02-23 00:00:00  1000010235
#
#                open_dt  exp_dt  cr_lmt_amt  prev_cr_lmt_amt
# 0  2010-12-20 00:00:00    1220     70000.0              0.0
# 1  2014-06-04 00:00:00     619     69000.0          60000.0
# 2  2014-01-22 00:00:00     119     27000.0          32000.0
# 3  2015-12-03 00:00:00    1220     41000.0              0.0
# 4  2014-06-24 00:00:00     619     50000.0          60000.0

# %%
card_df.describe()
# Out:
#             card_no      bill_cyc        cst_id        exp_dt    cr_lmt_amt  \
# count  1.187500e+04  11875.000000  1.187500e+04  11875.000000  1.187500e+04
# mean   1.234000e+15     16.536421  1.000007e+09    664.413474  1.114629e+05
# std    8.130275e+03      6.577258  4.122280e+03    339.860193  1.130223e+05
# min    1.234000e+15      5.000000  1.000000e+09    119.000000  0.000000e+00
# 25%    1.234000e+15     10.000000  1.000004e+09    417.000000  4.300000e+04
# 50%    1.234000e+15     17.000000  1.000007e+09    620.000000  7.800000e+04
# 75%    1.234000e+15     20.000000  1.000011e+09    921.000000  1.400000e+05
# max    1.234000e+15     25.000000  1.000014e+09   1221.000000  2.084780e+06
#
#        prev_cr_lmt_amt
# count     1.187500e+04
# mean      6.045589e+04
# std       1.240106e+05
# min       0.000000e+00
# 25%       0.000000e+00
# 50%       0.000000e+00
# 75%       7.800000e+04
# max       2.130796e+06

# %%
cust_df = pd.read_csv(custfile)
cust_df.head()
# Out:
#        cst_id  incm_amt   age  main_zip_cd  cr_line_amt               pos_dt
# 0  1000001115     47676  41.0        11110     100000.0  2017-02-23 00:00:00
# 1  1000004693     27157  52.0        10170      80000.0  2017-02-23 00:00:00
# 2  1000008370     20990  27.0        10900      52000.0  2017-02-23 00:00:00
# 3  1000004738     21879  33.0        10150      40000.0  2017-02-23 00:00:00
# 4  1000000044     71361  62.0        50100     178000.0  2017-02-23 00:00:00

# %%
cust_df.describe()
# Out:
#              cst_id      incm_amt          age   main_zip_cd   cr_line_amt
# count  9.544000e+03  9.544000e+03  9543.000000   9544.000000  9.544000e+03
# mean   1.000007e+09  6.573088e+04    40.837996  22906.977682  1.220528e+05
# std    4.083855e+03  1.067371e+05    10.332491  22631.783988  1.234623e+05
# min    1.000000e+09  0.000000e+00    22.000000  10050.000000  1.500000e+04
# 25%    1.000004e+09  2.331350e+04    33.000000  10250.000000  4.800000e+04
# 50%    1.000007e+09  4.000000e+04    39.000000  10800.000000  8.000000e+04
# 75%    1.000011e+09  7.209000e+04    48.000000  21140.000000  1.500000e+05
# max    1.000014e+09  3.859715e+06   117.000000  96180.000000  2.523000e+06

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Customer and Card Features

# %%
feature_df = pd.merge(card_df, cust_df, on='cst_id').set_index('card_no').loc[:, ['cr_lmt_amt', 'prev_cr_lmt_amt', 'incm_amt', 'age', 'main_zip_cd', 'cr_line_amt']]

# %% [markdown]
# ### Transaction Features

# %%
trx_amt_df = trx_df.loc[:, ['card_no', 'txn_amount']]
feature_df['amount_total'] = trx_amt_df.groupby(by='card_no').sum()
feature_df['amount_mean'] = trx_amt_df.groupby(by='card_no').mean()
feature_df['amount_median'] = trx_amt_df.groupby(by='card_no').median()
feature_df['amount_min'] = trx_amt_df.groupby(by='card_no').max()
feature_df['amount_max'] = trx_amt_df.groupby(by='card_no').min()
feature_df['count'] = trx_amt_df.groupby(by='card_no').count()

# %%
feature_df.fillna(0, inplace=True)
feature_df.head()
# Out:
#                   cr_lmt_amt  prev_cr_lmt_amt  incm_amt   age  main_zip_cd  \
# card_no
# 1234000000023349     70000.0              0.0     58650  67.0        10310
# 1234000000011770     70000.0              0.0     58650  67.0        10310
# 1234000000026921    140000.0          70000.0     58650  67.0        10310
# 1234000000007292     69000.0          60000.0     19989  25.0        10150
# 1234000000005196     25000.0              0.0     19989  25.0        10150
#
#                   cr_line_amt  amount_total  amount_mean  amount_median  \
# card_no
# 1234000000023349     140000.0       35800.0   436.585366          200.0
# 1234000000011770     140000.0       99550.0  4525.000000         1825.0
# 1234000000026921     140000.0       25650.0  3664.285714         1500.0
# 1234000000007292      69000.0       24800.0   442.857143          350.0
# 1234000000005196      69000.0        8850.0   327.777778          250.0
#
#                   amount_min  amount_max  count
# card_no
# 1234000000023349      7250.0        50.0     82
# 1234000000011770     13150.0       350.0     22
# 1234000000026921     10300.0       650.0      7
# 1234000000007292      2000.0        50.0     56
# 1234000000005196      1350.0       200.0     27

# %%
feature_df.describe()
# Out:
#          cr_lmt_amt  prev_cr_lmt_amt      incm_amt           age  \
# count  1.187500e+04     1.187500e+04  1.187500e+04  11875.000000
# mean   1.114629e+05     6.045589e+04  7.039686e+04     41.079579
# std    1.130223e+05     1.240106e+05  1.126346e+05     10.432623
# min    0.000000e+00     0.000000e+00  0.000000e+00      0.000000
# 25%    4.300000e+04     0.000000e+00  2.482450e+04     33.000000
# 50%    7.800000e+04     0.000000e+00  4.234700e+04     39.000000
# 75%    1.400000e+05     7.800000e+04  7.737350e+04     48.000000
# max    2.084780e+06     2.130796e+06  3.859715e+06    117.000000
#
#         main_zip_cd   cr_line_amt  amount_total    amount_mean  amount_median  \
# count  11875.000000  1.187500e+04  1.187500e+04   11875.000000   11875.000000
# mean   23098.611789  1.306273e+05  9.084867e+04    2037.039640    1120.254737
# std    22751.949361  1.317340e+05  3.493688e+05    5445.884778    3503.993864
# min    10050.000000  1.500000e+04  5.000000e+01      50.000000      50.000000
# 25%    10250.000000  5.000000e+04  2.260000e+04     601.191151     325.000000
# 50%    10800.000000  9.000000e+04  4.700000e+04    1029.545455     500.000000
# 75%    21150.000000  1.600000e+05  9.345000e+04    1933.387446     850.000000
# max    96180.000000  2.523000e+06  2.824490e+07  243490.517241  119900.000000
#
#          amount_min     amount_max         count
# count  1.187500e+04   11875.000000  11875.000000
# mean   1.682348e+04     387.077895     52.824505
# std    9.744652e+04    2794.419226     44.181193
# min    5.000000e+01      50.000000      1.000000
# 25%    3.000000e+03      50.000000     32.000000
# 50%    7.500000e+03     100.000000     43.000000
# 75%    1.345000e+04     200.000000     66.000000
# max    5.630400e+06  119900.000000    764.000000

# %% [markdown]
# ## Feature and Class Visualization

# %%
train_data = feature_df.loc[train_df.loc[:, 0]]
test_data = feature_df.loc[test_df.loc[:, 0]]

train_label = pd.DataFrame({'class': train_df.loc[:, 1]})

# %%
train_data.reset_index(drop=True, inplace=True)

train_visualization = pd.concat([train_data, train_label], axis=1)
train_visualization.head()
# Out:
#    cr_lmt_amt  prev_cr_lmt_amt  incm_amt   age  main_zip_cd  cr_line_amt  \
# 0    120000.0         140000.0    163591  36.0        72110     120000.0
# 1     90000.0         108000.0     90143  57.0        10510      90000.0
# 2    300000.0         500000.0    120000  56.0        10250     300000.0
# 3     20000.0              0.0     16000  29.0        51180      20000.0
# 4     20000.0              0.0     16281  26.0        10310      20000.0
#
#    amount_total  amount_mean  amount_median  amount_min  amount_max  count  \
# 0      129350.0  1847.857143          500.0     15800.0        50.0     70
# 1       16400.0   529.032258          250.0      3000.0       150.0     31
# 2       14000.0   736.842105          500.0      4000.0       200.0     19
# 3       21550.0   653.030303          550.0      3000.0        50.0     33
# 4       10450.0   254.878049          150.0       900.0        50.0     41
#
#    class
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0

# %% [markdown]
# ### Features

# %%
col_len = len(train_data.columns)

plt.figure(figsize=(12, 48))
gs = gridspec.GridSpec(col_len, 1)

for i, cn in enumerate(train_data.columns):
    ax = plt.subplot(gs[i])
    
    sns.distplot(train_visualization[cn][train_visualization['class'] == 0], bins=50, color='g')
    sns.distplot(train_visualization[cn][train_visualization['class'] == 1], bins=50, color='r')
    
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
    
plt.show()

# %% [markdown]
# ### Classes

# %%
plt.bar([0, 1], [len(train_label[train_label['class'] == 0]), len(train_label[train_label['class'] == 1])], color=['green', 'red'])
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### Validation Set Splitting

# %%
# Use 20% of labeled data as a validation set
msk = np.random.rand(len(train_data)) < 0.8

X1 = train_data[msk].values
t1 = train_label[msk].values

X2 = train_data[~msk].values
t2 = train_label[~msk].values

# %%
plt.bar([0, 1], [len(X1[t1 == 0]), len(X1[t1 == 1])], color=['green', 'red'])
plt.show()
# Out:
# C:\Users\Example\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 1; dimension is 12 but corresponding boolean dimension is 1
#   if __name__ == '__main__':

# %%
plt.bar([0, 1], [len(X2[t2 == 0]), len(X2[t2 == 1])], color=['green', 'red'])
plt.show()
# Out:
# C:\Users\Example\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 1; dimension is 12 but corresponding boolean dimension is 1
#   if __name__ == '__main__':

# %% [markdown]
# ### Build

# %%
from sklearn import svm

classifier = svm.SVC()
classifier.fit(X1, t1.ravel())

y1 = classifier.predict(X1)
y2 = classifier.predict(X2)

training_accuracy = float(sum(t1.ravel() == y1))/len(t1) * 100
validation_accuracy = float(sum(t2.ravel() == y2))/len(t2) * 100

print("training accuracy = %.2f%%" % training_accuracy)
print("validation accuracy = %.2f%%" % validation_accuracy)
# Out:
# training accuracy = 100.00%
# validation accuracy = 70.66%

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(t2.ravel(), y2)
# Out:
# array([[1358,    0],
#        [ 564,    0]])
